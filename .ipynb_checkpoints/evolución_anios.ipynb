# %% [markdown]
# ### Análisis de la evolución año tras año de las descargas de paquetes

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
from IPython.display import Image

# %%
evolucion=pd.read_csv("C:\\Users\\Joako\\Desktop\\AnalisisDatosEjercicios\\datos\\data_merge.csv")

# %% [markdown]
# Voy a análizar como evoluciono las descarga de paquetes por paises año tras año
# 1. Qué paises han descargado todos los años
# 2. Qué paises se fueron incorporando y a partir de que momento
# 3. Qué tipo de paquetes se descargaron y se hubo un cambio año a año

# %% [markdown]
# #### Inicio con el año 2016

# %%
# creo variable filtrando solo 2016

country_2016_down = evolucion.query('year_of_download == 2016')

date_country_2016 = country_2016_down.groupby(['country', 'software_package' ])['score'].sum().reset_index()
date_country_2016.head()

# Creación de pivot_table para graficar
pivot_country_2016 = date_country_2016.pivot(
    index='country',
    columns='software_package',
    values='score')

pivot_country_2016.head()
# Out:
# software_package  Basic  Plus  Premium
# country
# Bangladesh          NaN   8.0      NaN
# Belgium             NaN  15.0      NaN
# Colombia            5.0   NaN      NaN
# Finland            11.0  10.0      NaN
# France             10.0   7.0     15.0

# %%
# Creación de gráfico
pivot_country_2016.plot(kind='bar')

# Configurar el título y los ejes del gráfico
plt.title('Cantidad total de descargas por tipo de paquete año 2016')
plt.xlabel('Paises')
plt.ylabel('Cantidad de descargas')

plt.show()

# %% [markdown]
# #### Año 2017

# %%
# creo variable filtrando solo 2017

country_2017_down = evolucion.query('year_of_download == 2017')

date_country_2017 = country_2017_down.groupby(['country', 'software_package' ])['score'].sum().reset_index()
date_country_2017.head()

# Creación de pivot_table para graficar
pivot_country_2017 = date_country_2017.pivot(
    index='country',
    columns='software_package',
    values='score')

pivot_country_2017.head()
# Out:
# software_package  Basic  Plus  Premium
# country
# Bahamas             NaN   NaN     17.0
# Belgium             4.0   NaN      NaN
# Bermuda            11.0   NaN      NaN
# Canada              7.0   4.0      NaN
# China               2.0   NaN      5.0

# %%
# Creación de gráfico
pivot_country_2017.plot(kind='bar')

# Configurar el título y los ejes del gráfico
plt.title('Cantidad total de descargas por tipo de paquete año 2017')
plt.xlabel('Paises')
plt.ylabel('Cantidad de descargas')

plt.show()

# %% [markdown]
# #### Año 2018

# %%
# creo variable filtrando solo 2018

country_2018_down = evolucion.query('year_of_download == 2018')

date_country_2018 = country_2018_down.groupby(['country', 'software_package' ])['score'].sum().reset_index()
date_country_2018.head()

# Creación de pivot_table para graficar
pivot_country_2018 = date_country_2018.pivot(
    index='country',
    columns='software_package',
    values='score')

pivot_country_2018.head()
# Out:
# software_package  Basic  Plus  Premium
# country
# Bangladesh          NaN   9.0      8.0
# Belgium             7.0   NaN      NaN
# Finland            17.0   7.0      NaN
# Germany             NaN   NaN      8.0
# Iceland             NaN   NaN      4.0

# %%
# Creación de gráfico
pivot_country_2018.plot(kind='bar')

# Configurar el título y los ejes del gráfico
plt.title('Cantidad total de descargas por tipo de paquete año 2018')
plt.xlabel('Paises')
plt.ylabel('Cantidad de descargas')

plt.show()

# %% [markdown]
# #### Año 2019

# %%
# creo variable filtrando solo 2019

country_2019_down = evolucion.query('year_of_download == 2019')

date_country_2019 = country_2019_down.groupby(['country', 'software_package' ])['score'].sum().reset_index()
date_country_2019.head()

# Creación de pivot_table para graficar
pivot_country_2019 = date_country_2019.pivot(
    index='country',
    columns='software_package',
    values='score')

pivot_country_2019.head()
# Out:
# software_package  Basic  Plus  Premium
# country
# Bahamas             5.0   NaN      NaN
# Belgium             7.0   7.0      7.0
# Bermuda             7.0   NaN      NaN
# Colombia            NaN   2.0      NaN
# Finland            20.0   NaN      NaN

# %%
# Creación de gráfico
pivot_country_2019.plot(kind='bar')

# Configurar el título y los ejes del gráfico
plt.title('Cantidad total de descargas por tipo de paquete año 2019')
plt.xlabel('Paises')
plt.ylabel('Cantidad de descargas')

plt.show()

# %% [markdown]
# #### Año 2020

# %%
# creo variable filtrando solo 2020

country_2020_down = evolucion.query('year_of_download == 2020')

date_country_2020 = country_2020_down.groupby(['country', 'software_package' ])['score'].sum().reset_index()
date_country_2020.head()

# Creación de pivot_table para graficar
pivot_country_2020 = date_country_2020.pivot(
    index='country',
    columns='software_package',
    values='score')

pivot_country_2020.head()
# Out:
# software_package  Basic  Plus  Premium
# country
# Argentina           7.0   NaN      NaN
# Brazil              NaN   4.0      NaN
# Canada              NaN  11.0      NaN
# Chile               NaN   NaN      8.0
# China               NaN   8.0      NaN

# %%
# Creación de gráfico
pivot_country_2020.plot(kind='bar')

# Configurar el título y los ejes del gráfico
plt.title('Cantidad total de descargas por tipo de paquete año 2020')
plt.xlabel('Paises')
plt.ylabel('Cantidad de descargas')

plt.show()

# %% [markdown]
# ### Visualizar comportamiento de las descargas de paquetes por países y su evolución año tras año

# %%
Image(filename='C:/Users/Joako/Desktop/AnalisisDatosEjercicios/datos/imagenes/Comparacion_descargas_anual.png')
